# %% [markdown]
# <a href="https://colab.research.google.com/github/alextonon/ETL/blob/main/Donn%C3%A9es%20communes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


def extract_data(list_chemin):

    # print("📄 Reading tourism data from CSV...")

    try:

        df = pd.DataFrame()
        for chemin in list_chemin:
            df = pd.concat([df, pd.read_csv("../data/"+ chemin)], ignore_index=True)

        print('Data retreived in a dataframe')
        return df

    except Exception as e:
        print(f"❌ Error reading data: {e}")
        return pd.DataFrame()

# %%
df = pd.DataFrame(pd.read_csv("communes-france-2025.csv"))
df.shape
# Out:
# /tmp/ipykernel_8424/1236332959.py:1: DtypeWarning: Columns (1,12,14,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.DataFrame(pd.read_csv("communes-france-2025.csv"))
# (34935, 47)

# %%
#On ne garde que le 'nom_standard' dans pour la dénomination
df.drop(['nom_sans_pronom', 'nom_a', 'nom_de', 'nom_sans_accent','nom_standard_majuscule'], axis=1, inplace=True)
df.drop(['typecom', 'typecom_texte', 'canton_code', 'canton_nom', 'codes_postaux', 'academie_code',
         'academie_nom', 'code_unite_urbaine', 'nom_unite_urbaine', 'taille_unite_urbaine',
         'type_commune_unite_urbaine', 'statut_commune_unite_urbaine', 'superficie_hectare',
         'altitude_moyenne', 'altitude_minimale','altitude_maximale', 'latitude_centre', 'longitude_centre',
         'niveau_equipements_services', 'niveau_equipements_services_texte', 'gentile', 'url_wikipedia', 'url_villedereve'], axis=1, inplace=True)

# %%
df.shape
df.tail()
# Out:
#        Unnamed: 0 code_insee   nom_standard  reg_code  reg_nom dep_code  \
# 34930       34930      97613  M'Tsangamouji         6  Mayotte      976
# 34931       34931      97614       Ouangani         6  Mayotte      976
# 34932       34932      97615       Pamandzi         6  Mayotte      976
# 34933       34933      97616           Sada         6  Mayotte      976
# 34934       34934      97617       Tsingoni         6  Mayotte      976
#
#        dep_nom  epci_code            epci_nom  code_postal  zone_emploi  \
# 34930  Mayotte  200059871  CC du Centre-Ouest      97650.0        601.0
# 34931  Mayotte  200059871  CC du Centre-Ouest      97670.0        601.0
# 34932  Mayotte  200050532  CC de Petite-Terre      97615.0        601.0
# 34933  Mayotte  200059871  CC du Centre-Ouest      97640.0        601.0
# 34934  Mayotte  200059871  CC du Centre-Ouest      97680.0        601.0
#
#       code_insee_centre_zone_emploi  population  superficie_km2  densite  \
# 34930                           NaN        6432              22    298.0
# 34931                           NaN       10203              18    558.0
# 34932                           NaN       11442               4   2686.0
# 34933                           NaN       11156              11   1028.0
# 34934                           NaN       13934              34    407.0
#
#        latitude_mairie  longitude_mairie  grille_densite  \
# 34930          -12.761            45.084               3
# 34931          -12.849            45.139               3
# 34932          -12.798            45.275               2
# 34933          -12.847            45.106               2
# 34934          -12.790            45.105               2
#
#                  grille_densite_texte
# 34930                  Petites villes
# 34931                  Petites villes
# 34932  Centres urbains intermédiaires
# 34933  Centres urbains intermédiaires
# 34934  Centres urbains intermédiaires

# %% [markdown]
# * code_insee: Code commune, Code INSEE, Code assigné par l'INSEE à la commune
# * nom_standard: Nom normalisé de la commune, avec son article (ex: Le Havre)
# * reg_code: Code région assigné par l'INSEE à la région de la commune
# * reg_nom: Nom de la région où est située la commune
# * dep_code: Code département assigné par l'INSEE au département de la commune
# * dep_nom: Nom du département où est située la commune
# * epci_code: Code EPCI (établissements publics de coopération intercommunale) assigné par l'INSEE à la région de la commune
# * epci_nom: Nom de l'EPCI où est située la commune
# * code_postal: Code postal principal la commune
# * zone_emploi: Zone d'emploi de la commune, défini par l'INSEE
# * code_insee_centre_zone_emploi: Code INSEE de la commune centre de la zone d'emploi
# * population: Population municipale
# * superficie_km2: Superficie de la commune, en km2
# * densite: Densité de la commune, en habitant au km2
# * latitude_mairie: Latitude de la mairie
# * longitude_mairie: Longitude de la mairie
# * latitude_centre: Latitude du centroïde du territoire communale
# * longitude_centre: Longitude du centroïde du territoire communale
# * grille_densite: Grille communale de densité à 7 niveaux, selon l'INSEE
# * grille_densite_texte: Texte de la grille communale de densité à 7 niveaux, selon l'INSEE
# * niveau_equipements_services: Niveau des équipements et des services, selon l'INSEE (de 0 à 4)
# * niveau_equipements_services_texte: Texte du niveau des équipements et des services

# %%
#On enlève les départements d'Outre mer
df =df[~df['reg_nom'].isin(['Mayotte', 'Guyane', 'La Réunion', 'Guadeloupe', 'Martinique'])]
df.tail()
# Out:
#        Unnamed: 0 code_insee         nom_standard  reg_code        reg_nom  \
# 34801       34801      95676   Villers-en-Arthies        11  Île-de-France
# 34802       34802      95678        Villiers-Adam        11  Île-de-France
# 34803       34803      95680      Villiers-le-Bel        11  Île-de-France
# 34804       34804      95682      Villiers-le-Sec        11  Île-de-France
# 34805       34805      95690  Wy-dit-Joli-Village        11  Île-de-France
#
#       dep_code     dep_nom  epci_code  \
# 34801       95  Val-d'Oise  249500513
# 34802       95  Val-d'Oise  249500455
# 34803       95  Val-d'Oise  200055655
# 34804       95  Val-d'Oise  200073013
# 34805       95  Val-d'Oise  249500513
#
#                                             epci_nom  code_postal  \
# 34801                       CC du Vexin-Val de Seine      95510.0
# 34802  CC de la Vallée de l'Oise et des Trois Forêts      95840.0
# 34803                       CA Roissy Pays de France      95400.0
# 34804                     CC Carnelle Pays-de-France      95720.0
# 34805                       CC du Vexin-Val de Seine      95420.0
#
#        zone_emploi code_insee_centre_zone_emploi  population  superficie_km2  \
# 34801       1101.0                       95127.0         489               8
# 34802       1101.0                       95127.0         852              10
# 34803       1112.0                       93005.0       28836               7
# 34804       1112.0                       93005.0         196               3
# 34805       1101.0                       95127.0         329               8
#
#        densite  latitude_mairie  longitude_mairie  grille_densite  \
# 34801     58.0           49.088             1.725               6
# 34802     86.0           49.064             2.235               4
# 34803   3956.0           49.008             2.388               1
# 34804     61.0           49.072             2.390               6
# 34805     39.0           49.103             1.835               6
#
#            grille_densite_texte
# 34801  Rural à habitat dispersé
# 34802        Ceintures urbaines
# 34803    Grands centres urbains
# 34804  Rural à habitat dispersé
# 34805  Rural à habitat dispersé

# %%
df[df['dep_code']=='2A'].head(1)
# Out:
#        Unnamed: 0 code_insee nom_standard  reg_code reg_nom dep_code  \
# 10535       10535      2A001          Afa        94   Corse       2A
#
#             dep_nom  epci_code             epci_nom  code_postal  zone_emploi  \
# 10535  Corse-du-Sud  242010056  CA du Pays Ajaccien      20167.0       9401.0
#
#       code_insee_centre_zone_emploi  population  superficie_km2  densite  \
# 10535                         2A004        3336              12    278.0
#
#        latitude_mairie  longitude_mairie  grille_densite grille_densite_texte
# 10535           41.984             8.797               5        Bourgs ruraux

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# code_insee                        object
# nom_standard                      object
# reg_code                           int64
# reg_nom                           object
# dep_code                          object
# dep_nom                           object
# epci_code                         object
# epci_nom                          object
# code_postal                      float64
# zone_emploi                      float64
# code_insee_centre_zone_emploi     object
# population                         int64
# superficie_km2                     int64
# densite                          float64
# latitude_mairie                  float64
# longitude_mairie                 float64
# grille_densite                     int64
# grille_densite_texte              object
# dtype: object
